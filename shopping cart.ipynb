# %%
from roboflow import Roboflow
rf = Roboflow(api_key="uasfMDVNI0OQ8YNRAgCg")
project = rf.workspace().project("sku-nkiqm")
model = project.version(3).model

# infer on a local image
results = model.predict("item.png", confidence=40, overlap=30).json()

# visualize your prediction
# model.predict("trolley.jpg", confidence=40, overlap=30).save("prediction.jpg")

# infer on an image hosted elsewhere
# print(model.predict("URL_OF_YOUR_IMAGE", hosted=True, confidence=40, overlap=30).json())
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
xywh_values = []
labels1 = []

image_path = r"item.png"
image = Image.open(image_path)
for prediction in results['predictions']:   
    x, y, w, h, name= prediction['x'], prediction['y'], prediction['width'], prediction['height'], prediction['class']
    xywh_values.append((x, y, w, h))
    labels1.append(name)
    full_img = cv2.imread(r'') #shelf image
    
    x1 = int(x - w / 2)
    y1 = int(y - h / 2)
    x2 = int(x + w / 2)
    y2 = int(y + h / 2)
        # Extract the window region
        
    window = image.crop((x1, y1, x2, y2))
    
    plt.imshow(window)
    plt.axis('off')  
    plt.show()

# %%
import PIL

# %%
from PIL import Image

# %%
import cv2

# %%
import matplotlib.pyplot as plt
